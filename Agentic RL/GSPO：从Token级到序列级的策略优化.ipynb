# %% [markdown]
# # 0. 核心思想

# %% [markdown]
# 在 GRPO 中，其中的重要性采样比率 $\rho_{i,t}$ 是在 Token 级别定义的：
#
# $$\rho_{i,t} = \frac{\pi_{\theta}(y_{i,t} \mid x, y_{i,<t})}{\pi_{\theta_{\text{old}}}(y_{i,t} \mid x, y_{i,<t})}$$
#
# 同一个序列中不同 token 的更新幅度可能天差地别
